# %%
import pandas as pd
import seaborn as sns 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# lectura de los datos de entrenamiento

# %%
df = pd.read_csv("house_train_raw.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %% [markdown]
# graficos tipo scatter entre precio y features para entender la data

# %%
 #MSSubClass
sns.set_style("darkgrid")
plt.title("scatter sales vs MSSubClass")
sns.scatterplot(data=df, x="SalePrice", y="MSSubClass")
# Out:
# <AxesSubplot:title={'center':'scatter sales vs MSSubClass'}, xlabel='SalePrice', ylabel='MSSubClass'>

# %%
# scatter sales vs LotFrontage
sns.set_style("darkgrid")
plt.title("scatter sales vs LotFrontage")
sns.scatterplot(data=df, x="SalePrice", y="LotFrontage")
# Out:
# <AxesSubplot:title={'center':'scatter sales vs LotFrontage'}, xlabel='SalePrice', ylabel='LotFrontage'>

# %%
# scatter sales vs LotArea
sns.set_style("darkgrid")
plt.title("scatter sales vs LotArea")
sns.scatterplot(data=df, x="SalePrice", y="LotArea")
# Out:
# <AxesSubplot:title={'center':'scatter sales vs LotArea'}, xlabel='SalePrice', ylabel='LotArea'>

# %%
# TotalBsmtSF
sns.set_style("darkgrid")
plt.title("scatter sales vs TotalBsmtSF")
sns.scatterplot(data=df, x="SalePrice", y="TotalBsmtSF")
# Out:
# <AxesSubplot:title={'center':'scatter sales vs TotalBsmtSF'}, xlabel='SalePrice', ylabel='TotalBsmtSF'>

# %%
# OverallCond
sns.set_style("darkgrid")
plt.title("scatter sales vs GarageArea")
sns.scatterplot(data=df, x="SalePrice", y="GarageArea")
# Out:
# <AxesSubplot:title={'center':'scatter sales vs GarageArea'}, xlabel='SalePrice', ylabel='GarageArea'>

# %%
# YearBuilt
sns.set_style("darkgrid")
plt.title("scatter sales vs YearBuilt")
sns.scatterplot(data=df, x="SalePrice", y="YearBuilt")
# Out:
# <AxesSubplot:title={'center':'scatter sales vs YearBuilt'}, xlabel='SalePrice', ylabel='YearBuilt'>

# %%
# PoolArea
sns.set_style("darkgrid")
plt.title("scatter sales vs PoolArea")
sns.scatterplot(data=df, x="SalePrice", y="PoolArea")
# Out:
# <AxesSubplot:title={'center':'scatter sales vs PoolArea'}, xlabel='SalePrice', ylabel='PoolArea'>

# %%
# YearRemodAdd
sns.set_style("darkgrid")
plt.title("scatter sales vs YearRemodAdd")
sns.scatterplot(data=df, x="SalePrice", y="YearRemodAdd")
# Out:
# <AxesSubplot:title={'center':'scatter sales vs YearRemodAdd'}, xlabel='SalePrice', ylabel='YearRemodAdd'>

# %%
# MSSubClass
sns.set_style("darkgrid")
plt.title("scatter sales vs MSSubClass")
sns.scatterplot(data=df, x="SalePrice", y="MSSubClass")
# Out:
# <AxesSubplot:title={'center':'scatter sales vs MSSubClass'}, xlabel='SalePrice', ylabel='MSSubClass'>

# %%
# LandContour
sns.set_style("darkgrid")
plt.title("scatter sales vs LandContour")
sns.scatterplot(data=df, x="SalePrice", y="LandContour")
# Out:
# <AxesSubplot:title={'center':'scatter sales vs LandContour'}, xlabel='SalePrice', ylabel='LandContour'>

# %%
# LotConfig
sns.set_style("darkgrid")
plt.title("scatter sales vs LotConfig")
sns.scatterplot(data=df, x="SalePrice", y="LotConfig")
# Out:
# <AxesSubplot:title={'center':'scatter sales vs LotConfig'}, xlabel='SalePrice', ylabel='LotConfig'>

# %%
# Neighborhood
sns.set_style("darkgrid")
plt.title("scatter sales vs Neighborhood")
sns.scatterplot(data=df, x="SalePrice", y="Neighborhood")
# Out:
# <AxesSubplot:title={'center':'scatter sales vs Neighborhood'}, xlabel='SalePrice', ylabel='Neighborhood'>

# %%
# LowQualFinSF
sns.set_style("darkgrid")
plt.title("scatter sales vs LowQualFinSF")
sns.scatterplot(data=df, x="SalePrice", y="LowQualFinSF")
# Out:
# <AxesSubplot:title={'center':'scatter sales vs LowQualFinSF'}, xlabel='SalePrice', ylabel='LowQualFinSF'>

# %%
# MSSubClass
sns.set_style("darkgrid")
plt.title("histograma")
sns.histplot(data=df, x="SalePrice", hue='MSZoning')
# Out:
# <AxesSubplot:title={'center':'histograma'}, xlabel='SalePrice', ylabel='Count'>

# %%
# MSSubClass
sns.set_style("darkgrid")
plt.title("histograma")
sns.histplot(data=df, x="SalePrice", hue='MSSubClass')
# Out:
# <AxesSubplot:title={'center':'histograma'}, xlabel='SalePrice', ylabel='Count'>

# %%
# Alley
sns.set_style("darkgrid")
plt.title("histograma")
sns.histplot(data=df, x="SalePrice", hue='Alley')
# Out:
# <AxesSubplot:title={'center':'histograma'}, xlabel='SalePrice', ylabel='Count'>
